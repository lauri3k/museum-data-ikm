# %%
import os, glob, json
import pandas as pd
from IPython.display import display, HTML
from pathlib import Path

from src.utils import make_df

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

rijks_harvest_df = pd.read_csv(os.path.join("data", "rijks_harvest_complete_dataset.zip"), sep=";").reset_index(drop=True)
rijks_df = make_df(os.path.join('json', 'rijks')).reset_index(drop=True)

met_df = make_df('json/met').reset_index(drop=True)

# %% [markdown]
# ## Rijksmuseum data - Object Metadata API

# %%
rijks_df.head().style.set_properties(subset=['title', 'description'], **{'min-width': '20em'})
# Out:
# <style type="text/css">
# #T_b4ded_row0_col4, #T_b4ded_row0_col11, #T_b4ded_row1_col4, #T_b4ded_row1_col11, #T_b4ded_row2_col4, #T_b4ded_row2_col11, #T_b4ded_row3_col4, #T_b4ded_row3_col11, #T_b4ded_row4_col4, #T_b4ded_row4_col11 {
#   min-width: 20em;
# }
# </style>
# <table id="T_b4ded">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4ded_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_b4ded_level0_col1" class="col_heading level0 col1" >priref</th>
#       <th id="T_b4ded_level0_col2" class="col_heading level0 col2" >objectNumber</th>
#       <th id="T_b4ded_level0_col3" class="col_heading level0 col3" >language</th>
#       <th id="T_b4ded_level0_col4" class="col_heading level0 col4" >title</th>
#       <th id="T_b4ded_level0_col5" class="col_heading level0 col5" >copyrightHolder</th>
#       <th id="T_b4ded_level0_col6" class="col_heading level0 col6" >colors</th>
# ...

# %% [markdown]
# ## Rijksmuseum data - Object metadata harvesting API

# %%
rijks_harvest_df.head().style.set_properties(subset=['title', 'description'], **{'min-width': '20em'})
# Out:
# <style type="text/css">
# #T_7d870_row0_col1, #T_7d870_row0_col4, #T_7d870_row1_col1, #T_7d870_row1_col4, #T_7d870_row2_col1, #T_7d870_row2_col4, #T_7d870_row3_col1, #T_7d870_row3_col4, #T_7d870_row4_col1, #T_7d870_row4_col4 {
#   min-width: 20em;
# }
# </style>
# <table id="T_7d870">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d870_level0_col0" class="col_heading level0 col0" >identifier</th>
#       <th id="T_7d870_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_7d870_level0_col2" class="col_heading level0 col2" >creator</th>
#       <th id="T_7d870_level0_col3" class="col_heading level0 col3" >subject</th>
#       <th id="T_7d870_level0_col4" class="col_heading level0 col4" >description</th>
#       <th id="T_7d870_level0_col5" class="col_heading level0 col5" >date</th>
#       <th id="T_7d870_level0_col6" class="col_heading level0 col6" >type</th>
# ...

# %% [markdown]
# ## The Metropolitan Museum of Art Collection API

# %%
met_df.head().style.set_properties(subset=['title'], **{'min-width': '20em'})
# Out:
# <style type="text/css">
# #T_cb1e4_row0_col11, #T_cb1e4_row1_col11, #T_cb1e4_row2_col11, #T_cb1e4_row3_col11, #T_cb1e4_row4_col11 {
#   min-width: 20em;
# }
# </style>
# <table id="T_cb1e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb1e4_level0_col0" class="col_heading level0 col0" >objectID</th>
#       <th id="T_cb1e4_level0_col1" class="col_heading level0 col1" >isHighlight</th>
#       <th id="T_cb1e4_level0_col2" class="col_heading level0 col2" >accessionNumber</th>
#       <th id="T_cb1e4_level0_col3" class="col_heading level0 col3" >accessionYear</th>
#       <th id="T_cb1e4_level0_col4" class="col_heading level0 col4" >isPublicDomain</th>
#       <th id="T_cb1e4_level0_col5" class="col_heading level0 col5" >primaryImage</th>
#       <th id="T_cb1e4_level0_col6" class="col_heading level0 col6" >primaryImageSmall</th>
#       <th id="T_cb1e4_level0_col7" class="col_heading level0 col7" >additionalImages</th>
# ...
