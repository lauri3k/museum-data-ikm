# %%
import os, glob, json
import pandas as pd
from IPython.display import display, HTML
from pathlib import Path

from utils import make_df

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

rijks_harvest_df = pd.read_csv('rijks_harvest_complete_dataset.zip').reset_index(drop=True)
rijks_df = make_df('json/rijks').reset_index(drop=True)

met_df = make_df('json/met').reset_index(drop=True)

# %% [markdown]
# ## Rijksmuseum data - Object Metadata API

# %%
rijks_df.head().style.set_properties(subset=['title', 'description'], **{'min-width': '20em'})
# Out:
# <style type="text/css">
# #T_a3193_row0_col4, #T_a3193_row0_col11, #T_a3193_row1_col4, #T_a3193_row1_col11, #T_a3193_row2_col4, #T_a3193_row2_col11, #T_a3193_row3_col4, #T_a3193_row3_col11, #T_a3193_row4_col4, #T_a3193_row4_col11 {
#   min-width: 20em;
# }
# </style>
# <table id="T_a3193">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3193_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_a3193_level0_col1" class="col_heading level0 col1" >priref</th>
#       <th id="T_a3193_level0_col2" class="col_heading level0 col2" >objectNumber</th>
#       <th id="T_a3193_level0_col3" class="col_heading level0 col3" >language</th>
#       <th id="T_a3193_level0_col4" class="col_heading level0 col4" >title</th>
#       <th id="T_a3193_level0_col5" class="col_heading level0 col5" >copyrightHolder</th>
#       <th id="T_a3193_level0_col6" class="col_heading level0 col6" >colors</th>
#       <th id="T_a3193_level0_col7" class="col_heading level0 col7" >colorsWithNormalization</th>
#       <th id="T_a3193_level0_col8" class="col_heading level0 col8" >normalizedColors</th>
#       <th id="T_a3193_level0_col9" class="col_heading level0 col9" >normalized32Colors</th>
#       <th id="T_a3193_level0_col10" class="col_heading level0 col10" >titles</th>
#       <th id="T_a3193_level0_col11" class="col_heading level0 col11" >description</th>
#       <th id="T_a3193_level0_col12" class="col_heading level0 col12" >labelText</th>
#       <th id="T_a3193_level0_col13" class="col_heading level0 col13" >objectTypes</th>
#       <th id="T_a3193_level0_col14" class="col_heading level0 col14" >objectCollection</th>
#       <th id="T_a3193_level0_col15" class="col_heading level0 col15" >makers</th>
#       <th id="T_a3193_level0_col16" class="col_heading level0 col16" >principalMakers</th>
#       <th id="T_a3193_level0_col17" class="col_heading level0 col17" >plaqueDescriptionDutch</th>
#       <th id="T_a3193_level0_col18" class="col_heading level0 col18" >plaqueDescriptionEnglish</th>
#       <th id="T_a3193_level0_col19" class="col_heading level0 col19" >principalMaker</th>
#       <th id="T_a3193_level0_col20" class="col_heading level0 col20" >artistRole</th>
#       <th id="T_a3193_level0_col21" class="col_heading level0 col21" >associations</th>
#       <th id="T_a3193_level0_col22" class="col_heading level0 col22" >exhibitions</th>
#       <th id="T_a3193_level0_col23" class="col_heading level0 col23" >materials</th>
#       <th id="T_a3193_level0_col24" class="col_heading level0 col24" >techniques</th>
#       <th id="T_a3193_level0_col25" class="col_heading level0 col25" >productionPlaces</th>
#       <th id="T_a3193_level0_col26" class="col_heading level0 col26" >hasImage</th>
#       <th id="T_a3193_level0_col27" class="col_heading level0 col27" >historicalPersons</th>
#       <th id="T_a3193_level0_col28" class="col_heading level0 col28" >inscriptions</th>
#       <th id="T_a3193_level0_col29" class="col_heading level0 col29" >documentation</th>
#       <th id="T_a3193_level0_col30" class="col_heading level0 col30" >catRefRPK</th>
#       <th id="T_a3193_level0_col31" class="col_heading level0 col31" >principalOrFirstMaker</th>
#       <th id="T_a3193_level0_col32" class="col_heading level0 col32" >dimensions</th>
#       <th id="T_a3193_level0_col33" class="col_heading level0 col33" >physicalProperties</th>
#       <th id="T_a3193_level0_col34" class="col_heading level0 col34" >physicalMedium</th>
#       <th id="T_a3193_level0_col35" class="col_heading level0 col35" >longTitle</th>
#       <th id="T_a3193_level0_col36" class="col_heading level0 col36" >subTitle</th>
#       <th id="T_a3193_level0_col37" class="col_heading level0 col37" >scLabelLine</th>
#       <th id="T_a3193_level0_col38" class="col_heading level0 col38" >showImage</th>
#       <th id="T_a3193_level0_col39" class="col_heading level0 col39" >location</th>
#       <th id="T_a3193_level0_col40" class="col_heading level0 col40" >links.search</th>
#       <th id="T_a3193_level0_col41" class="col_heading level0 col41" >webImage.guid</th>
#       <th id="T_a3193_level0_col42" class="col_heading level0 col42" >webImage.offsetPercentageX</th>
#       <th id="T_a3193_level0_col43" class="col_heading level0 col43" >webImage.offsetPercentageY</th>
#       <th id="T_a3193_level0_col44" class="col_heading level0 col44" >webImage.width</th>
#       <th id="T_a3193_level0_col45" class="col_heading level0 col45" >webImage.height</th>
#       <th id="T_a3193_level0_col46" class="col_heading level0 col46" >webImage.url</th>
#       <th id="T_a3193_level0_col47" class="col_heading level0 col47" >acquisition.method</th>
#       <th id="T_a3193_level0_col48" class="col_heading level0 col48" >acquisition.date</th>
#       <th id="T_a3193_level0_col49" class="col_heading level0 col49" >acquisition.creditLine</th>
#       <th id="T_a3193_level0_col50" class="col_heading level0 col50" >dating.presentingDate</th>
#       <th id="T_a3193_level0_col51" class="col_heading level0 col51" >dating.sortingDate</th>
#       <th id="T_a3193_level0_col52" class="col_heading level0 col52" >dating.period</th>
#       <th id="T_a3193_level0_col53" class="col_heading level0 col53" >dating.yearEarly</th>
#       <th id="T_a3193_level0_col54" class="col_heading level0 col54" >dating.yearLate</th>
#       <th id="T_a3193_level0_col55" class="col_heading level0 col55" >classification.iconClassIdentifier</th>
#       <th id="T_a3193_level0_col56" class="col_heading level0 col56" >classification.iconClassDescription</th>
#       <th id="T_a3193_level0_col57" class="col_heading level0 col57" >classification.motifs</th>
#       <th id="T_a3193_level0_col58" class="col_heading level0 col58" >classification.events</th>
#       <th id="T_a3193_level0_col59" class="col_heading level0 col59" >classification.periods</th>
#       <th id="T_a3193_level0_col60" class="col_heading level0 col60" >classification.places</th>
#       <th id="T_a3193_level0_col61" class="col_heading level0 col61" >classification.people</th>
#       <th id="T_a3193_level0_col62" class="col_heading level0 col62" >classification.objectNumbers</th>
#       <th id="T_a3193_level0_col63" class="col_heading level0 col63" >label.title</th>
#       <th id="T_a3193_level0_col64" class="col_heading level0 col64" >label.makerLine</th>
#       <th id="T_a3193_level0_col65" class="col_heading level0 col65" >label.description</th>
#       <th id="T_a3193_level0_col66" class="col_heading level0 col66" >label.notes</th>
#       <th id="T_a3193_level0_col67" class="col_heading level0 col67" >label.date</th>
#       <th id="T_a3193_level0_col68" class="col_heading level0 col68" >permitDownload</th>
#       <th id="T_a3193_level0_col69" class="col_heading level0 col69" >links.self</th>
#       <th id="T_a3193_level0_col70" class="col_heading level0 col70" >links.web</th>
#       <th id="T_a3193_level0_col71" class="col_heading level0 col71" >headerImage.guid</th>
#       <th id="T_a3193_level0_col72" class="col_heading level0 col72" >headerImage.offsetPercentageX</th>
#       <th id="T_a3193_level0_col73" class="col_heading level0 col73" >headerImage.offsetPercentageY</th>
#       <th id="T_a3193_level0_col74" class="col_heading level0 col74" >headerImage.width</th>
#       <th id="T_a3193_level0_col75" class="col_heading level0 col75" >headerImage.height</th>
#       <th id="T_a3193_level0_col76" class="col_heading level0 col76" >headerImage.url</th>
#       <th id="T_a3193_level0_col77" class="col_heading level0 col77" >webImage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3193_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3193_row0_col0" class="data row0 col0" >en-SK-A-2291</td>
#       <td id="T_a3193_row0_col1" class="data row0 col1" >6531</td>
#       <td id="T_a3193_row0_col2" class="data row0 col2" >SK-A-2291</td>
#       <td id="T_a3193_row0_col3" class="data row0 col3" >en</td>
#       <td id="T_a3193_row0_col4" class="data row0 col4" >The Trekvliet Shipping Canal near Rijswijk, known as the ‘View near the Geest Bridge’</td>
#       <td id="T_a3193_row0_col5" clas

# %% [markdown]
# ## Rijksmuseum data - Object metadata harvesting API

# %%
rijks_harvest_df.head().style.set_properties(subset=['title', 'description'], **{'min-width': '20em'})
# Out:
# <style type="text/css">
# #T_ef2c5_row0_col1, #T_ef2c5_row0_col4, #T_ef2c5_row1_col1, #T_ef2c5_row1_col4, #T_ef2c5_row2_col1, #T_ef2c5_row2_col4, #T_ef2c5_row3_col1, #T_ef2c5_row3_col4, #T_ef2c5_row4_col1, #T_ef2c5_row4_col4 {
#   min-width: 20em;
# }
# </style>
# <table id="T_ef2c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef2c5_level0_col0" class="col_heading level0 col0" >identifier</th>
#       <th id="T_ef2c5_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_ef2c5_level0_col2" class="col_heading level0 col2" >creator</th>
#       <th id="T_ef2c5_level0_col3" class="col_heading level0 col3" >subject</th>
#       <th id="T_ef2c5_level0_col4" class="col_heading level0 col4" >description</th>
#       <th id="T_ef2c5_level0_col5" class="col_heading level0 col5" >date</th>
#       <th id="T_ef2c5_level0_col6" class="col_heading level0 col6" >type</th>
#       <th id="T_ef2c5_level0_col7" class="col_heading level0 col7" >format</th>
#       <th id="T_ef2c5_level0_col8" class="col_heading level0 col8" >language</th>
#       <th id="T_ef2c5_level0_col9" class="col_heading level0 col9" >publisher</th>
#       <th id="T_ef2c5_level0_col10" class="col_heading level0 col10" >rights</th>
#       <th id="T_ef2c5_level0_col11" class="col_heading level0 col11" >coverage</th>
#       <th id="T_ef2c5_level0_col12" class="col_heading level0 col12" >contributor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef2c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef2c5_row0_col0" class="data row0 col0" >BK-AM-33</td>
#       <td id="T_ef2c5_row0_col1" class="data row0 col1" >Pleurants van het praalgraf van Isabella van Bourbon</td>
#       <td id="T_ef2c5_row0_col2" class="data row0 col2" >Thienen, Renier van (I)</td>
#       <td id="T_ef2c5_row0_col3" class="data row0 col3" >Bourbon, Isabella de</td>
#       <td id="T_ef2c5_row0_col4" class="data row0 col4" >In 1465 overleed Isabella van Bourbon, de vrouw van Karel de Stoute, hertog van Bourgondië. Hun dochter Maria liet voor haar een praalgraf maken in de Michielsabdij in Antwerpen. Om de tombe stonden 24 beeldjes van rouwende familieleden en voorouders, zogenoemde pleurants. Ze symboliseerden het belang van de Bourgondische dynastie.</td>
#       <td id="T_ef2c5_row0_col5" class="data row0 col5" >ca. 1475 - ca. 1476</td>
#       <td id="T_ef2c5_row0_col6" class="data row0 col6" >graffiguur</td>
#       <td id="T_ef2c5_row0_col7" class="data row0 col7" >brons</td>
#       <td id="T_ef2c5_row0_col8" class="data row0 col8" >nl</td>
#       <td id="T_ef2c5_row0_col9" class="data row0 col9" >Rijksmuseum</td>
#       <td id="T_ef2c5_row0_col10" class="data row0 col10" >http://creativecommons.org/publicdomain/mark/1.0/</td>
#       <td id="T_ef2c5_row0_col11" class="data row0 col11" >Brussel (stad)</td>
#       <td id="T_ef2c5_row0_col12" class="data row0 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef2c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ef2c5_row1_col0" class="data row1 col0" >SK-C-1368</td>
#       <td id="T_ef2c5_row1_col1" class="data row1 col1" >Portretten van Giuliano en Francesco Giamberti da Sangallo</td>
#       <td id="T_ef2c5_row1_col2" class="data row1 col2" >Piero di Cosimo</td>
#       <td id="T_ef2c5_row1_col3" class="data row1 col3" >Sangallo, Giuliano da</td>
#       <td id="T_ef2c5_row1_col4" class="data row1 col4" >Op dit uitzonderlijke tweeluik is de vooraanstaande Florentijnse architect Giuliano da Sangallo geportretteerd met zijn pas overleden vader Francesco, die architect en musicus was. Ze behoren tot de vroegste voorbeelden van portretten waarin het beroep van de afgebeelden centraal staat. Pen en passer duiden op de bouwkunst, het blad met noten op de muziek; beide kunsten zijn gebaseerd op harmonie en verhoudingen.</td>
#       <td id="T_ef2c5_row1_col5" class="data row1 col5" >1482 - 1485</td>
#       <td id="T_ef2c5_row1_col6" class="data row1 col6" >schilderij</td>
#       <td id="T_ef2c5_row1_col7" class="data row1 col7" >olieverf</td>
#       <td id="T_ef2c5_row1_col8" class="data row1 col8" >nl</td>
#       <td id="T_ef2c5_row1_col9" class="data row1 col9" >Rijksmuseum</td>
#       <td id="T_ef2c5_row1_col10" class="data row1 col10" >http://creativecommons.org/publicdomain/mark/1.0/</td>
#       <td id="T_ef2c5_row1_col11" class="data row1 col11" >Florence</td>
#       <td id="T_ef2c5_row1_col12" class="data row1 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef2c5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ef2c5_row2_col0" class="data row2 col0" >SK-C-5</td>
#       <td id="T_ef2c5_row2_col1" class="data row2 col1" >De Nachtwacht</td>
#       <td id="T_ef2c5_row2_col2" class="data row2 col2" >Rijn, Rembrandt van</td>
#       <td id="T_ef2c5_row2_col3" class="data row2 col3" >Heede, Jan van der</td>
#       <td id="T_ef2c5_row2_col4" class="data row2 col4" >Rembrandts beroemdste en grootste schilderij werd gemaakt voor de Kloveniersdoelen. Dit was een van de drie hoofdkwartieren van de Amsterdamse schutterij, de burgerwacht van de stad. Rembrandt was de eerste die op een schuttersstuk alle figuren in actie weergaf. De kapitein, in het zwart, geeft zijn luitenant opdracht dat de compagnie moet gaan marcheren. De schutters stellen zich op. Met behulp van licht vestigde Rembrandt de aandacht op belangrijke details, zoals het handgebaar van de kapitein en het kleine meisje op de voorgrond. Zij is de mascotte van de schutters. De naam Nachtwacht is pas veel later ontstaan, toen men dacht dat het om een nachtelijk tafereel ging.</td>
#       <td id="T_ef2c5_row2_col5" class="data row2 col5" >1642</td>
#       <td id="T_ef2c5_row2_col6" class="data row2 col6" >schilderij</td>
#       <td id="T_ef2c5_row2_col7" class="data row2 col7" >olieverf</td>
#       <td id="T_ef2c5_row2_col8" class="data row2 col8" >nl</td>
#       <td id="T_ef2c5_row2_col9" class="data row2 col9" >Rijksmuseum</td>
#       <td id="T_ef2c5_row2_col10" class="data row2 col10" >http://creativecommons.org/publicdomain/mark/1.0/</td>
#       <td id="T_ef2c5_row2_col11" class="data row2 col11" >Amsterdam</td>
#       <td id="T_ef2c5_row2_col12" class="data row2 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef2c5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ef2c5_row3_col0" class="data row3 col0" >SK-C-597</td>
#       <td id="T_ef2c5_row3_col1" class="data row3 col1" >Portret van een vrouw, mogelijk Maria Trip</td>
#       <td id="T_ef2c5_row3_col2" class="data row3 col2" >Rijn, Rembrandt van</td>
#       <td id="T_ef2c5_row3_col3" class="data row3 col3" >Trip, Maria</td>
#       <td id="T_ef2c5_row3_col4" class="data row3 col4" >Maria’s vader was schatrijk geworden door handel in ijzer en wapens. In 1639 is zij 20 jaar en nog ongetrouwd. Op dit portret komt ze er onverbloemd voor uit dat ze iets te besteden heeft. Haar halsdoek is van de fijnst mogelijke, bijna transparante kant, en ze draagt een weelde aan parels. De vouwwaaier in haar linkerhand was in 1639 nog een zeldzaam en kostbaar kleinood.</td>
#       <td id="T_ef2c5_row3_col5" class="data row3 col5" >1639</td>
#       <td id="T_ef2c5_row3_col6" class="data row3 col6" >schilderij</td>
#       <td id="T_ef2c5_row3_col7" class="data row3 col7" >olieverf</td>
#       <td id="T_ef2c5_row3_col8" class="data row3 col8" >nl</td>
#       <td id="T_ef2c5_row3_col9" class="data row3 col9" >Rijksmuseum</td>
#       <td id="T_ef2c5_row3_col10" class="data row3 col10" >http://creativecommons.org/publicdomain/mark/1.0/</td>
#       <td id="T_ef2c5_row3_col11" class="data row3 col11" >nan</td>
#       <td id="T_ef2c5_row3_col12" class="data row3 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ef2c5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ef2c5_row4_col0" class="data row4 col0" >SK-C-217</td>
#       <td id="T_ef2c5_row4_col1" class="data row4 col1" >Interieur van de Sint-Odulphuskerk in Assendelft</td>
#       <td id="T_ef2c5_row4_col2" class="data row4 col2" >Saenredam, Pieter Jans

# %% [markdown]
# ## The Metropolitan Museum of Art Collection API

# %%
met_df.head().style.set_properties(subset=['title'], **{'min-width': '20em'})
# Out:
# <style type="text/css">
# #T_90a76_row0_col11, #T_90a76_row1_col11, #T_90a76_row2_col11, #T_90a76_row3_col11, #T_90a76_row4_col11 {
#   min-width: 20em;
# }
# </style>
# <table id="T_90a76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90a76_level0_col0" class="col_heading level0 col0" >objectID</th>
#       <th id="T_90a76_level0_col1" class="col_heading level0 col1" >isHighlight</th>
#       <th id="T_90a76_level0_col2" class="col_heading level0 col2" >accessionNumber</th>
#       <th id="T_90a76_level0_col3" class="col_heading level0 col3" >accessionYear</th>
#       <th id="T_90a76_level0_col4" class="col_heading level0 col4" >isPublicDomain</th>
#       <th id="T_90a76_level0_col5" class="col_heading level0 col5" >primaryImage</th>
#       <th id="T_90a76_level0_col6" class="col_heading level0 col6" >primaryImageSmall</th>
#       <th id="T_90a76_level0_col7" class="col_heading level0 col7" >additionalImages</th>
#       <th id="T_90a76_level0_col8" class="col_heading level0 col8" >constituents</th>
#       <th id="T_90a76_level0_col9" class="col_heading level0 col9" >department</th>
#       <th id="T_90a76_level0_col10" class="col_heading level0 col10" >objectName</th>
#       <th id="T_90a76_level0_col11" class="col_heading level0 col11" >title</th>
#       <th id="T_90a76_level0_col12" class="col_heading level0 col12" >culture</th>
#       <th id="T_90a76_level0_col13" class="col_heading level0 col13" >period</th>
#       <th id="T_90a76_level0_col14" class="col_heading level0 col14" >dynasty</th>
#       <th id="T_90a76_level0_col15" class="col_heading level0 col15" >reign</th>
#       <th id="T_90a76_level0_col16" class="col_heading level0 col16" >portfolio</th>
#       <th id="T_90a76_level0_col17" class="col_heading level0 col17" >artistRole</th>
#       <th id="T_90a76_level0_col18" class="col_heading level0 col18" >artistPrefix</th>
#       <th id="T_90a76_level0_col19" class="col_heading level0 col19" >artistDisplayName</th>
#       <th id="T_90a76_level0_col20" class="col_heading level0 col20" >artistDisplayBio</th>
#       <th id="T_90a76_level0_col21" class="col_heading level0 col21" >artistSuffix</th>
#       <th id="T_90a76_level0_col22" class="col_heading level0 col22" >artistAlphaSort</th>
#       <th id="T_90a76_level0_col23" class="col_heading level0 col23" >artistNationality</th>
#       <th id="T_90a76_level0_col24" class="col_heading level0 col24" >artistBeginDate</th>
#       <th id="T_90a76_level0_col25" class="col_heading level0 col25" >artistEndDate</th>
#       <th id="T_90a76_level0_col26" class="col_heading level0 col26" >artistGender</th>
#       <th id="T_90a76_level0_col27" class="col_heading level0 col27" >artistWikidata_URL</th>
#       <th id="T_90a76_level0_col28" class="col_heading level0 col28" >artistULAN_URL</th>
#       <th id="T_90a76_level0_col29" class="col_heading level0 col29" >objectDate</th>
#       <th id="T_90a76_level0_col30" class="col_heading level0 col30" >objectBeginDate</th>
#       <th id="T_90a76_level0_col31" class="col_heading level0 col31" >objectEndDate</th>
#       <th id="T_90a76_level0_col32" class="col_heading level0 col32" >medium</th>
#       <th id="T_90a76_level0_col33" class="col_heading level0 col33" >dimensions</th>
#       <th id="T_90a76_level0_col34" class="col_heading level0 col34" >measurements</th>
#       <th id="T_90a76_level0_col35" class="col_heading level0 col35" >creditLine</th>
#       <th id="T_90a76_level0_col36" class="col_heading level0 col36" >geographyType</th>
#       <th id="T_90a76_level0_col37" class="col_heading level0 col37" >city</th>
#       <th id="T_90a76_level0_col38" class="col_heading level0 col38" >state</th>
#       <th id="T_90a76_level0_col39" class="col_heading level0 col39" >county</th>
#       <th id="T_90a76_level0_col40" class="col_heading level0 col40" >country</th>
#       <th id="T_90a76_level0_col41" class="col_heading level0 col41" >region</th>
#       <th id="T_90a76_level0_col42" class="col_heading level0 col42" >subregion</th>
#       <th id="T_90a76_level0_col43" class="col_heading level0 col43" >locale</th>
#       <th id="T_90a76_level0_col44" class="col_heading level0 col44" >locus</th>
#       <th id="T_90a76_level0_col45" class="col_heading level0 col45" >excavation</th>
#       <th id="T_90a76_level0_col46" class="col_heading level0 col46" >river</th>
#       <th id="T_90a76_level0_col47" class="col_heading level0 col47" >classification</th>
#       <th id="T_90a76_level0_col48" class="col_heading level0 col48" >rightsAndReproduction</th>
#       <th id="T_90a76_level0_col49" class="col_heading level0 col49" >linkResource</th>
#       <th id="T_90a76_level0_col50" class="col_heading level0 col50" >metadataDate</th>
#       <th id="T_90a76_level0_col51" class="col_heading level0 col51" >repository</th>
#       <th id="T_90a76_level0_col52" class="col_heading level0 col52" >objectURL</th>
#       <th id="T_90a76_level0_col53" class="col_heading level0 col53" >tags</th>
#       <th id="T_90a76_level0_col54" class="col_heading level0 col54" >objectWikidata_URL</th>
#       <th id="T_90a76_level0_col55" class="col_heading level0 col55" >isTimelineWork</th>
#       <th id="T_90a76_level0_col56" class="col_heading level0 col56" >GalleryNumber</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90a76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90a76_row0_col0" class="data row0 col0" >729</td>
#       <td id="T_90a76_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_90a76_row0_col2" class="data row0 col2" >46.140.8</td>
#       <td id="T_90a76_row0_col3" class="data row0 col3" >1946</td>
#       <td id="T_90a76_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_90a76_row0_col5" class="data row0 col5" >https://images.metmuseum.org/CRDImages/ad/original/174196.jpg</td>
#       <td id="T_90a76_row0_col6" class="data row0 col6" >https://images.metmuseum.org/CRDImages/ad/web-large/174196.jpg</td>
#       <td id="T_90a76_row0_col7" class="data row0 col7" >[]</td>
#       <td id="T_90a76_row0_col8" class="data row0 col8" >None</td>
#       <td id="T_90a76_row0_col9" class="data row0 col9" >The American Wing</td>
#       <td id="T_90a76_row0_col10" class="data row0 col10" >Bowl</td>
#       <td id="T_90a76_row0_col11" class="data row0 col11" >Footed bowl</td>
#       <td id="T_90a76_row0_col12" class="data row0 col12" >American</td>
#       <td id="T_90a76_row0_col13" class="data row0 col13" ></td>
#       <td id="T_90a76_row0_col14" class="data row0 col14" ></td>
#       <td id="T_90a76_row0_col15" class="data row0 col15" ></td>
#       <td id="T_90a76_row0_col16" class="data row0 col16" ></td>
#       <td id="T_90a76_row0_col17" class="data row0 col17" ></td>
#       <td id="T_90a76_row0_col18" class="data row0 col18" ></td>
#       <td id="T_90a76_row0_col19" class="data row0 col19" ></td>
#       <td id="T_90a76_row0_col20" class="data row0 col20" ></td>
#       <td id="T_90a76_row0_col21" class="data row0 col21" ></td>
#       <td id="T_90a76_row0_col22" class="data row0 col22" ></td>
#       <td id="T_90a76_row0_col23" class="data row0 col23" ></td>
#       <td id="T_90a76_row0_col24" class="data row0 col24" ></td>
#       <td id="T_90a76_row0_col25" class="data row0 col25" ></td>
#       <td id="T_90a76_row0_col26" class="data row0 col26" ></td>
#       <td id="T_90a76_row0_col27" class="data row0 col27" ></td>
#       <td id="T_90a76_row0_col28" class="data row0 col28" ></td>
#       <td id="T_90a76_row0_col29" class="data row0 col29" >1850–70</td>
#       <td id="T_90a76_row0_col30" class="data row0 col30" >1850</td>
#       <td id="T_90a76_row0_col31" class="data row0 col31" >1870</td>
#       <td id="T_90a76_row0_col32" class="data row0 col32" >Pressed glass</td>
#       <td id="T_90a76_row0_col33" class="data row0 col33" >H. 4 in. (10.2 cm); Diam. 6 3/4 in. (17.1 cm)</td>
#       <td id="T_90a76_row0_col34" class="data row0 col34" >[{'elementName': 'Other', 'elementDescription': None, 'elementMeasurements': {'Diameter': 17.145, 'Height': 10.16}}]</td>
#       <td id="T_90a76_row0_col35" class="data row0 col35" >Gift of Mrs.
